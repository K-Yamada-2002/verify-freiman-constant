# %% [markdown]
# # Schecker proof 2
#
# Numerical checks for the continued-fraction intervals used in proof 2.
# The active verification pipeline appears first; older experiments are
# retained in the stashed section at the end of the notebook.

# %% [markdown]
# ## Core continued-fraction and $H$ utilities

# %%
# utility
_cf_value_cache = {}

def cf_value(terms):
    # return continued_fraction of terms as a real number (cached)
    key = tuple(tuple(part) for part in terms)
    if key not in _cf_value_cache:
        _cf_value_cache[key] = continued_fraction(terms).n()
    return _cf_value_cache[key]

# fixed eta endpoints used in H (cached)
_ETA_1 = None
_ETA_2 = None

def _eta_endpoints():
    global _ETA_1, _ETA_2
    if _ETA_1 is None:
        _ETA_1 = cf_value([(0,), (1, 3)])
        _ETA_2 = cf_value([(0,), (3, 1)])
    return _ETA_1, _ETA_2

# %%
# functions related to G and H
def G(r, s, t, v, xv=None):
    # xv=None returns a lightweight numeric callable; otherwise numeric value.
    # Pure arithmetic — no symbolic var/subs (symbolic path was the bottleneck).
    r, s, t, v = float(r), float(s), float(t), float(v)
    def Gx(x):
        x = float(x)
        return (1.0 + r * x) * (1.0 + s * x) / ((1.0 + t * x) * (1.0 + v * x))
    return Gx if xv is None else Gx(xv)

def H(s_1, s_2, r_2, r_1, c_plus, c_minus):
    eta_1, eta_2 = _eta_endpoints()
    return (
        ((s_1 - s_2) / (r_2 - r_1))
        * G(r_2, r_1, eta_1, eta_2, c_plus)
        * G(eta_1, eta_2, s_1, s_2, c_minus)
    )

def _g_extrema_on_interval(r, s, t, v, x_range):
    """Extrema of G(r,s,t,v; x) on [lo, hi] by endpoints + analytic critical points.
    G = (1+(r+s)x+rs x^2)/(1+(t+v)x+tv x^2); G'=0 reduces to a quadratic.
    """
    lo, hi = float(x_range[0]), float(x_range[1])
    r, s, t, v = float(r), float(s), float(t), float(v)
    if r == t and s == v:
        g = G(r, s, t, v, lo)
        return (g, lo), (g, hi)

    a0, a1, a2 = 1.0, r + s, r * s
    b0, b1, b2 = 1.0, t + v, t * v
    # N'D - ND' = A x^2 + B x + C  (x^3 cancels)
    A = a2 * b1 - a1 * b2
    B = 2.0 * (a2 * b0 - a0 * b2)
    C = a1 * b0 - a0 * b1

    xs = [lo, hi]
    eps = 1e-14
    if abs(A) < eps:
        if abs(B) >= eps:
            x0 = -C / B
            if lo <= x0 <= hi:
                xs.append(x0)
    else:
        disc = B * B - 4.0 * A * C
        if disc >= 0:
            sqrt_disc = disc ** 0.5
            for x0 in ((-B + sqrt_disc) / (2.0 * A), (-B - sqrt_disc) / (2.0 * A)):
                if lo <= x0 <= hi:
                    xs.append(x0)

    valued = [(G(r, s, t, v, x0), x0) for x0 in xs]
    return min(valued, key=lambda item: item[0]), max(valued, key=lambda item: item[0])

_H_extrema_cache = {}

def compute_H_extrema(s_1, s_2, r_2, r_1, c_minus_range=(0.2, 0.9), c_plus_range=(0.2, 0.9)):
    key = (
        float(s_1), float(s_2), float(r_2), float(r_1),
        float(c_minus_range[0]), float(c_minus_range[1]),
        float(c_plus_range[0]), float(c_plus_range[1]),
    )
    if key in _H_extrema_cache:
        return _H_extrema_cache[key]

    eta_1, eta_2 = _eta_endpoints()
    g1 = _g_extrema_on_interval(r_2, r_1, eta_1, eta_2, c_plus_range)
    g2 = _g_extrema_on_interval(eta_1, eta_2, s_1, s_2, c_minus_range)
    candidates = [
        (H(s_1, s_2, r_2, r_1, c_plus, c_minus), c_plus, c_minus)
        for _, c_plus in g1
        for _, c_minus in g2
    ]
    result = (
        min(candidates, key=lambda item: item[0]),
        max(candidates, key=lambda item: item[0]),
    )
    _H_extrema_cache[key] = result
    return result

# %% [markdown]
# ## Condition (iii): endpoint selection and admissible ranges

# %%
# select T-interval endpoints for successors
_ETA_EXTS = ((3, 1), (1, 3))
_THETA_EXTS = ((2, 1), (1, 2))
_DEFAULT_V_A_LO = RR(1)
_DEFAULT_V_A_HI = RR(17) / 5

def _condition_iii_v_bounds_from_H_extrema(h, k, r_diff, min_H, max_H):
    """Return (x_lower, x_upper) for condition (iii); each may be None if unconstrained."""
    if r_diff == 0:
        return None, None
    sign_h = (-1) ** h
    sign_k = (-1) ** k
    sigma = (-1) ** (h + k)
    
    if sigma > 0:
        if sign_h * r_diff > 0:
            return max(sign_k * min_H, sign_k * max_H), None
        return None, min(sign_k * min_H, sign_k * max_H)

    if sign_h * r_diff > 0:
        return None, min(sign_k * min_H, sign_k * max_H)
    return max(sign_k * min_H, sign_k * max_H), None

def _format_condition_iii_constraint(x_lo, x_hi):
    if x_lo is not None and x_hi is None:
        return f"x >= {x_lo}"
    if x_lo is None and x_hi is not None:
        return f"x <= {x_hi}"
    if x_lo is None and x_hi is None:
        return "no restriction"
    return f"{x_lo} <= x <= {x_hi}"

def _v_bounds_cover_interval(x_lo, x_hi, v_lo, v_hi):
    """True iff the x-range contains [v_lo, v_hi].
    None on an x endpoint means unconstrained on that side.
    """
    v_lo, v_hi = float(v_lo), float(v_hi)
    if x_lo is not None and float(x_lo) > v_lo:
        return False
    if x_hi is not None and float(x_hi) < v_hi:
        return False
    return True


def _v_bounds_complement(x_lo, x_hi):
    """Complement of [x_lo, x_hi] as a list of (lo, hi) pieces. None = unbounded."""
    if x_lo is None and x_hi is None:
        return []
    if x_lo is None:
        return [(x_hi, None)]
    if x_hi is None:
        return [(None, x_lo)]
    return [(None, x_lo), (x_hi, None)]


def _single_v_complement(x_lo, x_hi):
    """Single complement piece when the x-range is one-sided; else the full list."""
    comps = _v_bounds_complement(x_lo, x_hi)
    if len(comps) == 1:
        return comps[0]
    return comps


def _condition_iii_v_bounds_for_pairing(cand, other, h, k):
    """Condition-(iii) x-range treating cand as (s_1, r_1) and other as (s_2, r_2)."""
    s1, r1 = cand
    s2, r2 = other
    r1_val, r2_val = cf_value(r1), cf_value(r2)
    r_diff = r2_val - r1_val
    if r_diff == 0:
        min_H = max_H = None
        x_lo, x_hi = None, None
    else:
        s1_val, s2_val = cf_value(s1), cf_value(s2)
        (min_H, _, _), (max_H, _, _) = compute_H_extrema(s1_val, s2_val, r2_val, r1_val)
        x_lo, x_hi = _condition_iii_v_bounds_from_H_extrema(h, k, r_diff, min_H, max_H)
    return {
        "candidate": cand,
        "min_H": min_H,
        "max_H": max_H,
        "r_1_val": r1_val,
        "r_2_val": r2_val,
        "r_diff": r_diff,
        "x_lower": x_lo,
        "x_upper": x_hi,
        "constraint": _format_condition_iii_constraint(x_lo, x_hi),
    }


def _select_pairings_for_v_range(candidates, v_lo, v_hi, h, k, left_or_right):
    """Keep pairing candidates whose condition-(iii) x-range covers [v_lo, v_hi].

    Each candidate is treated as (s_1, r_1) against the other as (s_2, r_2).
    _condition_iii_v_bounds_from_H_extrema gives the v(A) range that condition (iii) would
    allow; if that range does not cover [v_lo, v_hi] the candidate is dropped.
    """
    assert len(candidates) == 2
    a, b = candidates[0], candidates[1]
    bound_a_le_b = _condition_iii_v_bounds_for_pairing(a, b, h, k)
    bound_b_le_a = _condition_iii_v_bounds_for_pairing(b, a, h, k)
    bound_a_le_b["in_v_range"] = _v_bounds_cover_interval(
        bound_a_le_b["x_lower"], bound_a_le_b["x_upper"], v_lo, v_hi
    )
    bound_b_le_a["in_v_range"] = _v_bounds_cover_interval(
        bound_b_le_a["x_lower"], bound_b_le_a["x_upper"], v_lo, v_hi
    )

    viable = []
    viable_range = []
    if left_or_right == "left":
        if not bound_a_le_b["in_v_range"]:
            viable.append(b)
            viable_range.append(_single_v_complement(
                bound_a_le_b["x_lower"], bound_a_le_b["x_upper"]
            ))
        if not bound_b_le_a["in_v_range"]:
            viable.append(a)
            viable_range.append(_single_v_complement(
                bound_b_le_a["x_lower"], bound_b_le_a["x_upper"]
            ))
    if left_or_right == "right":
        if not bound_b_le_a["in_v_range"]:
            viable.append(b)
            viable_range.append(_single_v_complement(
                bound_b_le_a["x_lower"], bound_b_le_a["x_upper"]
            ))
        if not bound_a_le_b["in_v_range"]:
            viable.append(a)
            viable_range.append(_single_v_complement(
                bound_a_le_b["x_lower"], bound_a_le_b["x_upper"]
            ))

    info = {
        "H_bounds": (bound_a_le_b, bound_b_le_a),
        "viable_range": viable_range,
    }
    return tuple(viable), info


def _successor_endpoint_pairing_candidates(successor, h, k, parity_offset=0):
    """Two (eta/theta) pairings for T-interval beginning (0) or end (1)."""
    return (
        (
            [(0, *successor[0]), _ETA_EXTS[(len(successor[0]) + h + parity_offset) % 2]],
            [(0, *successor[1]), _THETA_EXTS[(len(successor[1]) + k + parity_offset) % 2]],
        ),
        (
            [(0, *successor[0]), _THETA_EXTS[(len(successor[0]) + h + parity_offset) % 2]],
            [(0, *successor[1]), _ETA_EXTS[(len(successor[1]) + k + parity_offset) % 2]],
        ),
    )

def select_successor_endpoint_pairs(successors, h, k, v_lo=None, v_hi=None):
    """Build sr_1 / sr_2 candidate lists from successors.

    Each sr_1[j] / sr_2[j] is a tuple of (s_terms, r_terms) pairs, filtered by
    whether the condition-(iii) x-range covers [v_lo, v_hi]. Also returns
    per-successor selection info.
    """
    if v_lo is None:
        v_lo = _DEFAULT_V_A_LO
    if v_hi is None:
        v_hi = _DEFAULT_V_A_HI

    sr_1, sr_2, details = [], [], []
    for j, successor in enumerate(successors):
        sr1_cands = _successor_endpoint_pairing_candidates(successor, h, k, parity_offset=0)
        sr1_kept, sr1_info = _select_pairings_for_v_range(
            sr1_cands, v_lo, v_hi, h, k, "left"
        )
        sr_1.append(sr1_kept)

        sr2_cands = _successor_endpoint_pairing_candidates(successor, h, k, parity_offset=1)
        sr2_kept, sr2_info = _select_pairings_for_v_range(
            sr2_cands, v_lo, v_hi, h, k, "right"
        )
        sr_2.append(sr2_kept)

        details.append({
            "j": j,
            "successor": successor,
            "sr_1": sr1_kept,
            "sr_1_info": sr1_info,
            "sr_2": sr2_kept,
            "sr_2_info": sr2_info,
        })
    return sr_1, sr_2, details

# %%
def compute_condition_iii_v_bounds(successors, h, k, sr_1=None, sr_2=None, v_lo=None, v_hi=None):
    """Return the v(A) range forced by condition (iii) across successor pairs.

    Compares sr_1[j] with sr_2[j-1] for j = 1, ..., len(successors)-1.
    If sr_1 / sr_2 are omitted, they are built via select_successor_endpoint_pairs.
    """

    # Known inequality for each (s_1, s_2, r_1, r_2):
    #   (-1)^h * x * (r_2 - r_1) >= (-1)^k * (r_2 - r_1) * H(s_1, s_2, r_2, r_1, c_plus, c_minus)
    # Equivalent form (when r_2 != r_1):
    #   (r_2 - r_1) * (-1)^h * (x - (-1)^{h+k} * H) >= 0
    # So with sigma = (-1)^{h+k}:
    #   if (r_2 - r_1) * (-1)^h > 0:  x >= sigma * H
    #   if (r_2 - r_1) * (-1)^h < 0:  x <= sigma * H
    # H varies in [min_H, max_H] as c_plus, c_minus vary; we take the bound
    # forced for every such H (worst-case over the H-range).

    if sr_1 is None or sr_2 is None:
        sr_1, sr_2, _ = select_successor_endpoint_pairs(successors, h, k, v_lo, v_hi)

    sign_h = (-1) ** h
    sign_k = (-1) ** k
    sigma = sign_h * sign_k
    by_j = {}

    for j in range(1, len(successors)):
        records = []
        for s_1, r_1 in sr_1[j]:
            for s_2, r_2 in sr_2[j - 1]:
                r_1_val = cf_value(r_1)
                r_2_val = cf_value(r_2)
                r_diff = r_2_val - r_1_val
                (min_H, _, _), (max_H, _, _) = compute_H_extrema(
                    cf_value(s_1), cf_value(s_2), r_2_val, r_1_val
                )
                x_lo, x_hi = _condition_iii_v_bounds_from_H_extrema(h, k, r_diff, min_H, max_H)

                if r_diff > 0:
                    r_larger = "r_2"
                elif r_diff < 0:
                    r_larger = "r_1"
                else:
                    r_larger = "equal"

                records.append({
                    "min_H": min_H,
                    "max_H": max_H,
                    "r_1_val": r_1_val,
                    "r_2_val": r_2_val,
                    "r_diff": r_diff,
                    "r_larger": r_larger,
                    "x_lower": x_lo,
                    "x_upper": x_hi,
                    "constraint": _format_condition_iii_constraint(x_lo, x_hi),
                    "r_1": r_1,
                    "r_2": r_2,
                    "s_1": s_1,
                    "s_2": s_2,
                })

        lowers = [rec["x_lower"] for rec in records if rec["x_lower"] is not None]
        uppers = [rec["x_upper"] for rec in records if rec["x_upper"] is not None]
        by_j[j] = {
            "records": records,
            # take most permissive bounds
            "x_lower": min(lowers) if lowers else None,
            "x_upper": max(uppers) if uppers else None,
        }

    all_lowers = [
        data["x_lower"]
        for data in by_j.values()
        if data["x_lower"] is not None
    ]
    all_uppers = [
        data["x_upper"]
        for data in by_j.values()
        if data["x_upper"] is not None
    ]

    return {
        "x_lower": max(all_lowers) if all_lowers else None,
        "x_upper": min(all_uppers) if all_uppers else None,
        "by_j": by_j,
        "sign_h": sign_h,
        "sign_k": sign_k,
        "sigma": sigma,
    }

# %%
def H_first_exceeds_second_everywhere(
    s_1_1, s_2_1, r_2_1, r_1_1, s_1_2, s_2_2, r_2_2, r_1_2,
    c_minus_range=(0.2, 0.9), c_plus_range=(0.2, 0.9),
):
    """Compare H(s_1_1, s_2_1, r_2_1, r_1_1, c_plus, c_minus) and
    H(s_1_2, s_2_2, r_2_2, r_1_2, c_plus, c_minus).

    returns True if H(s_1_1, s_2_1, r_2_1, r_1_1, c_plus, c_minus) > H(s_1_2, s_2_2, r_2_2, r_1_2, c_plus, c_minus)
    """

    """
    Hilfsatz 3:
    H(a,b,c,d ;x, y) >= H(e,f,g,h ;x, y)
    is equivalent to
    G(c, d, g, h) * (a - b) / (c - d) >= G(a, b, e, f) * (e - f) / (g - h)
    """

    a, b, c, d = map(float, (s_1_1, s_2_1, r_2_1, r_1_1))
    e, f, g, h = map(float, (s_1_2, s_2_2, r_2_2, r_1_2))
    if abs(c - d) < 1e-15 or abs(g - h) < 1e-15:
        raise ValueError("H undefined when r_2 == r_1")

    # LHS = α1 G(c,d,g,h; x) depends only on c_plus
    # RHS = α2 G(a,b,e,f; y) depends only on c_minus
    # For all (x,y) iff min_x (α1 G_plus(x)) > max_y (α2 G_minus(y))
    alpha1 = (a - b) / (c - d)
    alpha2 = (e - f) / (g - h)
    g_plus_min, g_plus_max = _g_extrema_on_interval(c, d, g, h, c_plus_range)
    g_minus_min, g_minus_max = _g_extrema_on_interval(a, b, e, f, c_minus_range)
    lhs_vals = (alpha1 * g_plus_min[0], alpha1 * g_plus_max[0])
    rhs_vals = (alpha2 * g_minus_min[0], alpha2 * g_minus_max[0])
    return min(lhs_vals) > max(rhs_vals)

# %%
def _r_larger_label(r_diff):
    if r_diff > 0:
        return "r_2"
    if r_diff < 0:
        return "r_1"
    return "equal"


def _condition_iii_identifies_upper_bound(sign_h, sigma, r_diff):
    if r_diff == 0:
        return False
    if sigma == 1:
        return sign_h * r_diff < 0
    return sign_h * r_diff > 0


def _condition_iii_identifies_lower_bound(sign_h, sigma, r_diff):
    if r_diff == 0:
        return False
    if sigma == 1:
        return sign_h * r_diff > 0
    return sign_h * r_diff < 0


def check_condition_iii_transition(successors_1, successors_2, h, k, v_lo=None, v_hi=None):
    """Compare (iii) upper-bound pairs of successors_1 with lower-bound pairs of successors_2.

    A pair from side 1 is kept only if it identifies an upper bound of v(A);
    a pair from side 2 only if it identifies a lower bound. For each such
    combination, record whether the resulting upper bound stays above
    the lower bound on the whole (c_plus, c_minus) range (Hilfsatz 3).
    For sigma < 0 this reverses the order of the H comparison.

    Returns a log dict in the same style as compute_condition_iii_v_bounds: by_pair records plus
    overall counts. Use print_condition_iii_transition_details to inspect.
    """
    if v_lo is None:
        v_lo = 1
    if v_hi is None:
        v_hi = 3.4
    sr_1_1, sr_2_1, details_1 = select_successor_endpoint_pairs(successors_1, h, k, v_lo, v_hi)
    sr_1_2, sr_2_2, details_2 = select_successor_endpoint_pairs(successors_2, h, k, v_lo, v_hi)
    sign_h = (-1) ** h
    sign_k = (-1) ** k
    sigma = sign_h * sign_k

    by_pair = {}
    records = []

    def _endpoint_pairs_with_details(sr_j, detail_j, which):
        x_ranges = detail_j[f"{which}_info"]["viable_range"]
        kept = list(sr_j)
        if len(x_ranges) != len(kept):
            x_ranges = list(x_ranges) + [None] * max(0, len(kept) - len(x_ranges))
        for (s, r), x_range in zip(kept, x_ranges):
            yield s, r, x_range

    for j_1 in range(1, len(successors_1)):
        detail_1_left = details_1[j_1]
        detail_1_right = details_1[j_1 - 1]
        for s_1_1, r_1_1, range_1_1 in _endpoint_pairs_with_details(sr_1_1[j_1], detail_1_left, "sr_1"):
            s_1_1_val, r_1_1_val = cf_value(s_1_1), cf_value(r_1_1)
            for s_2_1, r_2_1, range_2_1 in _endpoint_pairs_with_details(sr_2_1[j_1 - 1], detail_1_right, "sr_2"):
                s_2_1_val, r_2_1_val = cf_value(s_2_1), cf_value(r_2_1)
                r_diff_1 = r_2_1_val - r_1_1_val
                if not _condition_iii_identifies_upper_bound(sign_h, sigma, r_diff_1):
                    continue
                for j_2 in range(1, len(successors_2)):
                    detail_2_left = details_2[j_2]
                    detail_2_right = details_2[j_2 - 1]
                    for s_1_2, r_1_2, range_1_2 in _endpoint_pairs_with_details(sr_1_2[j_2], detail_2_left, "sr_1"):
                        s_1_2_val, r_1_2_val = cf_value(s_1_2), cf_value(r_1_2)
                        for s_2_2, r_2_2, range_2_2 in _endpoint_pairs_with_details(sr_2_2[j_2 - 1], detail_2_right, "sr_2"):
                            s_2_2_val, r_2_2_val = cf_value(s_2_2), cf_value(r_2_2)
                            r_diff_2 = r_2_2_val - r_1_2_val
                            if not _condition_iii_identifies_lower_bound(sign_h, sigma, r_diff_2):
                                continue

                            lowers = [range_1_1[0], range_2_1[0], range_1_2[0], range_2_2[0]]
                            lowers = [l for l in lowers if l is not None]
                            uppers = [range_1_1[1], range_2_1[1], range_1_2[1], range_2_2[1]]
                            uppers = [u for u in uppers if u is not None]
                            
                            max_lower = max(lowers) if lowers else None
                            min_upper = min(uppers) if uppers else None

                            if not (max_lower is None or min_upper is None) and max_lower > min_upper:       
                                continue

                            if sigma > 0:
                                greater_H_args = (
                                    s_1_1_val, s_2_1_val, r_2_1_val, r_1_1_val
                                )
                                lesser_H_args = (
                                    s_1_2_val, s_2_2_val, r_2_2_val, r_1_2_val
                                )
                                comparison_order = "upper_H > lower_H"
                            else:
                                greater_H_args = (
                                    s_1_2_val, s_2_2_val, r_2_2_val, r_1_2_val
                                )
                                lesser_H_args = (
                                    s_1_1_val, s_2_1_val, r_2_1_val, r_1_1_val
                                )
                                comparison_order = "lower_H > upper_H"
                            h1_greater = H_first_exceeds_second_everywhere(
                                *greater_H_args, *lesser_H_args
                            )
                            rec = {
                                "j_1": j_1,
                                "j_2": j_2,
                                "h1_greater": h1_greater,
                                "bound_order_valid": h1_greater,
                                "comparison_order": comparison_order,
                                "successor_1": detail_1_left["successor"],
                                "successor_1_prev": detail_1_right["successor"],
                                "successor_2": detail_2_left["successor"],
                                "successor_2_prev": detail_2_right["successor"],
                                "viable_range_1_1": range_1_1,
                                "viable_range_2_1": range_2_1,
                                "viable_range_1_2": range_1_2,
                                "viable_range_2_2": range_2_2,
                                "sr_1_info_1": detail_1_left["sr_1_info"],
                                "sr_2_info_1": detail_1_right["sr_2_info"],
                                "sr_1_info_2": detail_2_left["sr_1_info"],
                                "sr_2_info_2": detail_2_right["sr_2_info"],
                                "r_1_1": r_1_1,
                                "r_2_1": r_2_1,
                                "s_1_1": s_1_1,
                                "s_2_1": s_2_1,
                                "r_1_2": r_1_2,
                                "r_2_2": r_2_2,
                                "s_1_2": s_1_2,
                                "s_2_2": s_2_2,
                                "r_1_1_val": r_1_1_val,
                                "r_2_1_val": r_2_1_val,
                                "s_1_1_val": s_1_1_val,
                                "s_2_1_val": s_2_1_val,
                                "r_1_2_val": r_1_2_val,
                                "r_2_2_val": r_2_2_val,
                                "s_1_2_val": s_1_2_val,
                                "s_2_2_val": s_2_2_val,
                                "r_diff_1": r_diff_1,
                                "r_diff_2": r_diff_2,
                                "r_larger_1": _r_larger_label(r_diff_1),
                                "r_larger_2": _r_larger_label(r_diff_2),
                            }
                            records.append(rec)
                            by_pair.setdefault((j_1, j_2), {"records": []})
                            by_pair[(j_1, j_2)]["records"].append(rec)

    for pair, data in by_pair.items():
        data["all_h1_greater"] = all(rec["h1_greater"] for rec in data["records"])

    n_compared = len(records)
    n_h1_greater = sum(1 for rec in records if rec["h1_greater"])
    return {
        "records": records,
        "by_pair": by_pair,
        "n_compared": n_compared,
        "n_h1_greater": n_h1_greater,
        "all_h1_greater": bool(records) and n_h1_greater == n_compared,
        "sign_h": sign_h,
        "sign_k": sign_k,
        "sigma": sigma,
    }

# %%
def check_condition_iii_bounds_compatible(iii):
    """Check that condition (iii) leaves a nonempty v(A)-range.

    Every upper-bound record is compared with every lower-bound record.
    The comparison is pointwise for all c_plus and c_minus, using
    Hilfsatz 3 through H_first_exceeds_second_everywhere.  If only one kind of
    bound occurs, the allowed range is unbounded on the other side and
    is therefore nonempty.
    """
    records = [
        (j, record)
        for j, data in iii["by_j"].items()
        for record in data["records"]
    ]
    upper_records = [
        (j, record) for j, record in records
        if record["x_upper"] is not None
    ]
    lower_records = [
        (j, record) for j, record in records
        if record["x_lower"] is not None
    ]

    def _H_args_from_record(record):
        return (
            cf_value(record["s_1"]),
            cf_value(record["s_2"]),
            record["r_2_val"],
            record["r_1_val"],
        )

    comparisons = []
    for upper_j, upper_record in upper_records:
        for lower_j, lower_record in lower_records:
            # Pointwise nonemptiness is sigma*H_lower < sigma*H_upper.
            # Thus the order of the H comparison reverses for sigma < 0.
            if iii["sigma"] > 0:
                greater_record, lesser_record = upper_record, lower_record
                greater_kind, lesser_kind = "upper", "lower"
            else:
                greater_record, lesser_record = lower_record, upper_record
                greater_kind, lesser_kind = "lower", "upper"
            nonempty = H_first_exceeds_second_everywhere(
                *_H_args_from_record(greater_record), *_H_args_from_record(lesser_record)
            )
            comparisons.append({
                "upper_j": upper_j,
                "lower_j": lower_j,
                "upper_record": upper_record,
                "lower_record": lower_record,
                "greater_kind": greater_kind,
                "lesser_kind": lesser_kind,
                "nonempty_for_all_c": nonempty,
            })

    return {
        "upper_records": upper_records,
        "lower_records": lower_records,
        "comparisons": comparisons,
        "n_upper": len(upper_records),
        "n_lower": len(lower_records),
        "n_compared": len(comparisons),
        "n_nonempty": sum(
            comparison["nonempty_for_all_c"]
            for comparison in comparisons
        ),
        "all_nonempty_for_all_c": all(
            comparison["nonempty_for_all_c"]
            for comparison in comparisons
        ),
        "sigma": iii["sigma"],
    }


def print_condition_iii_compatibility(result):
    print(
        "iii nonempty for every (c_plus, c_minus): "
        f"upper={result['n_upper']}, lower={result['n_lower']}, "
        f"compared={result['n_compared']}, "
        f"passed={result['n_nonempty']}, "
        f"all={result['all_nonempty_for_all_c']}"
    )

# %% [markdown]
# ## Hilfsatz 4

# %%
_HILFSATZ4_V_LO = RR(5) / 17
_HILFSATZ4_V_HI = RR(17) / 5

def _hilfsatz4_successor_v_bounds(successor):
    """Per-successor Hilfsatz 4 bounds: v(A) in ((5/17) * max|H|, (17/5) * min|H|)."""
    r_1 = [(0, *successor[0]), _ETA_EXTS[0]]
    r_2 = [(0, *successor[0]), _ETA_EXTS[1]]
    s_1 = [(0, *successor[1]), _ETA_EXTS[0]]
    s_2 = [(0, *successor[1]), _ETA_EXTS[1]]
    (min_H, _, _), (max_H, _, _) = compute_H_extrema(
        cf_value(r_1), cf_value(r_2), cf_value(s_1), cf_value(s_2)
    )
    min_abs_H = min(abs(min_H), abs(max_H))
    max_abs_H = max(abs(min_H), abs(max_H))
    return {
        "successor": successor,
        "min_H": min_H,
        "max_H": max_H,
        "min_abs_H": min_abs_H,
        "max_abs_H": max_abs_H,
        "x_lower": _HILFSATZ4_V_LO * max_abs_H,
        "x_upper": _HILFSATZ4_V_HI * min_abs_H,
        "r_1": r_1,
        "r_2": r_2,
        "s_1": s_1,
        "s_2": s_2,
    }

def compute_hilfsatz4_common_v_bounds(successors):
    """Return the v(A) range forced by Hilfsatz 4 admissibility across successors.

    For each successor j, Hilfsatz 4 gives
      v(~u |~ w) = v(A) / |H(r_1, r_2, s_1, s_2; c_plus, c_minus)| 
    with r_i = [0; u + eta_i], s_i = [0; w + eta_i], hence
      v(A) in ((5/17) * max|H|, (17/5) * min|H|).
    The overall range is the intersection of these open intervals.
    """
    by_j = {}
    for j, successor in enumerate(successors):
        record = _hilfsatz4_successor_v_bounds(successor)
        record["j"] = j
        by_j[j] = record

    return {
        "x_lower": max(rec["x_lower"] for rec in by_j.values()),
        "x_upper": min(rec["x_upper"] for rec in by_j.values()),
        "by_j": by_j,
    }

# %% [markdown]
# ## Case families 2.1--2.6

# %%
# Each entry is a family of cases whose v(A)-ranges are checked together.
ORIGINAL_CASES = [
    # Case 2.1
    {
        "hk": [(0, 0), (1, 1)],
        "v_range": (1, 1.98),
        "cases": [
        {
            "intervals": [
                ([2], [2]),
                ([3], [1, 1]),
                ([2, 3], [2, 3]),
                ([1, 1, 3], [3, 1]),
                ([1], []),
            ],
        },
        {
            "intervals": [
                ([2], [2]),
                ([3], [1, 2]),
                ([2], [1]),
                ([1], []),
            ],
        },
    ],
    },
    # Case 2.2
    {
        "hk": [(0, 0), (1, 1)],
        "v_range": (1, 1.98),
        "cases": [
        {
            "intervals": [
                ([3], [2]),
                ([2], [3]),
                ([2], [2]),
            ],
        },
        {
            "intervals": [
                ([3], [2]),
                ([2, 1], [3]),
                ([2, 2], [3, 1]),
                ([2], [2]),
            ],
        },
        {
            "intervals": [
                ([3], [2]),
                ([2, 1], [3]),
                ([2, 1, 3], [2, 1, 3]),
                ([2], [2]),
            ],
        },
    ],
    },
    # Case 2.3
    {
        "hk": [(0, 0), (1, 1)],
        "v_range": (1.98, 3.4),
        "cases": [
        {
            "intervals": [
                ([3], [2]),
                ([2, 1, 3], [3, 1]),
                ([2], []),
                ([1], []),
            ],
        },
        {
            "intervals": [
                ([3], [2]),
                ([3, 1, 3], [1, 1, 3]),
                ([2, 1, 3], [3, 1]),
                ([2], []),
                ([1], []),
            ],
        },
        {
            "intervals": [
                ([3], [2]),
                ([3, 3], [2, 3]),
                ([3], [1]),
                ([2], []),
                ([1], []),
            ],
        },
    ],
    },
    # Case 2.4
    {
        "hk": [(0, 1), (1, 0)],
        "v_range": (1, 1.9),
        "cases": [
        {
            "intervals": [
                ([2], [1]),
                ([3], [2]),
                ([2, 1, 3], [2, 3]),
                ([2], [2]),
                ([1], []),
            ],
        },
        {
            "intervals": [
                ([2], [1]),
                ([3], [2]),
                ([3, 3], [2, 1, 3]),
                ([2, 1, 3], [2, 3]),
                ([2], [2]),
                ([1], []),
            ],
        },
        {
            "intervals": [
                ([2], [1]),
                ([3], [3]),
                ([1], []),
            ],
        },
        {
            "intervals": [
                ([2], [1]),
                ([2], [2]),
                ([1], []),
            ],
        },
    ],
    },
    # Case 2.5
    {
        "hk": [(0, 1), (1, 0)],
        "v_range": (1, 1.9),
        "cases": [
        {
            "intervals": [
                ([3], [1, 2]),
                ([2, 1, 3], [1, 3, 1]),
                ([2], [1]),
            ],
        },
        {
            "intervals": [
                ([3], [1, 2]),
                ([3, 3], [1, 2, 3]),
                ([3], [1, 1]),
                ([2], [1]),
            ],
        },
    ],
    },
    # Case 2.6
    {
        "hk": [(0, 1), (1, 0)],
        "v_range": (1.9, 3.4),
        "cases": [
        {
            "intervals": [
                ([3], [1]),
                ([2], []),
                ([1], []),
            ],
        },
        {
            "intervals": [
                ([3], [1]),
                ([2, 1, 3], [1, 3]),
                ([2], [1]),
                ([1], []),
            ],
        },
        {
            "intervals": [
                ([3], [1]),
                ([3, 3], [1, 1, 3]),
                ([2, 1, 3], [1, 3]),
                ([2], []),
                ([1], []),
            ],
        },
        {
            "intervals": [
                ([3], [1]),
                ([3], [2]),
                ([2], []),
                ([1], []),
            ],
        },
    ],
    },
]


def swap_case_directions(case):
    """Swap the negative and positive directions in one case."""
    return {
        "intervals": [
            (positive_side, negative_side)
            for negative_side, positive_side in case["intervals"]
        ],
    }


def swap_case_family_directions(case_family):
    """Swap all cases and family-level (h, k) types."""
    return {
        "cases": [swap_case_directions(case) for case in case_family["cases"]],
        "hk": [(h, k) for h, k in case_family["hk"]],
        "v_range": case_family["v_range"],
    }

# %%
case_families = [
    swap_case_family_directions(case_family)
    for case_family in ORIGINAL_CASES
]
MARGIN = 0.01

# %% [markdown]
# ## Sequential case-family verification
#
# For each family, check every case internally, apply the Hilfsatz 4
# admissibility bounds, connect adjacent cases, and verify that the first
# and last cases cover the family endpoints.

# %%
def _intersect_v_bounds(*ranges):
    """Intersect ranges whose None endpoints mean unbounded."""
    lowers = [lower for lower, _ in ranges if lower is not None]
    uppers = [upper for _, upper in ranges if upper is not None]
    return (
        max(lowers) if lowers else None,
        min(uppers) if uppers else None,
    )


def _v_bounds_are_nonempty(v_range):
    lower, upper = v_range
    return lower is None or upper is None or lower < upper


def _v_bounds_cover(outer, inner):
    outer_lower, outer_upper = outer
    inner_lower, inner_upper = inner
    lower_ok = outer_lower is None or outer_lower <= inner_lower
    upper_ok = outer_upper is None or outer_upper >= inner_upper
    return lower_ok and upper_ok


def verify_case_family_v_cover(case_family, margin=MARGIN):
    """Run condition-(iii), connectivity, and Hilfsatz-4 checks for a family.

    The first case is checked on the family's full v(A)-range. For each later
    case, the preceding case's condition-(iii)/Hilfsatz-4 upper bound, minus
    margin, becomes the lower endpoint of the next checked range.
    """
    h, k = case_family["hk"][0]
    family_v_lo, family_v_hi = case_family["v_range"]
    cases = case_family["cases"]
    results = []
    previous_case = None
    previous_combined_range = None

    for case_index, case in enumerate(cases):
        if previous_case is None:
            checked_v_range = (family_v_lo, family_v_hi)
            connection = None
        else:
            previous_upper = previous_combined_range[1]
            if previous_upper is None:
                raise ValueError(
                    f"case {case_index - 1} has no finite combined upper bound"
                )
            effective_previous_upper = min(previous_upper, family_v_hi)
            checked_v_range = (
                max(family_v_lo, effective_previous_upper - margin),
                family_v_hi,
            )
            connection = check_condition_iii_transition(
                previous_case["intervals"],
                case["intervals"],
                h,
                k,
                *checked_v_range,
            )

        sr_1, sr_2, sr_details = select_successor_endpoint_pairs(
            case["intervals"], h, k, *checked_v_range
        )
        iii = compute_condition_iii_v_bounds(
            case["intervals"],
            h,
            k,
            sr_1=sr_1,
            sr_2=sr_2,
            v_lo=checked_v_range[0],
            v_hi=checked_v_range[1],
        )
        internal_nonempty = check_condition_iii_bounds_compatible(iii)
        hilfsatz4 = compute_hilfsatz4_common_v_bounds(case["intervals"])
        iii_range = (iii["x_lower"], iii["x_upper"])
        hilfsatz4_range = (
            hilfsatz4["x_lower"], hilfsatz4["x_upper"]
        )
        combined_range = _intersect_v_bounds(iii_range, hilfsatz4_range)
        checked_combined_range = _intersect_v_bounds(
            combined_range, checked_v_range
        )
        static_intersection_nonempty = _v_bounds_are_nonempty(
            checked_combined_range
        )
        assigned_upper = min(
            upper
            for upper in (
                iii_range[1], hilfsatz4_range[1], family_v_hi
            )
            if upper is not None
        )
        assigned_v_range = (checked_v_range[0], assigned_upper)
        assigned_range_nonempty = _v_bounds_are_nonempty(assigned_v_range)
        hilfsatz4_covers_assigned_range = _v_bounds_cover(
            hilfsatz4_range, assigned_v_range
        )

        results.append({
            "case_index": case_index,
            "checked_v_range": checked_v_range,
            "previous_upper": (
                None
                if previous_combined_range is None
                else previous_combined_range[1]
            ),
            "effective_previous_upper": (
                None
                if previous_combined_range is None
                else min(previous_combined_range[1], family_v_hi)
            ),
            "sr_1": sr_1,
            "sr_2": sr_2,
            "sr_details": sr_details,
            "iii": iii,
            "internal_nonempty": internal_nonempty,
            "hilfsatz4": hilfsatz4,
            "iii_range": iii_range,
            "hilfsatz4_range": hilfsatz4_range,
            "combined_range": combined_range,
            "checked_combined_range": checked_combined_range,
            "static_intersection_nonempty": static_intersection_nonempty,
            "assigned_v_range": assigned_v_range,
            "assigned_range_nonempty": assigned_range_nonempty,
            "hilfsatz4_covers_assigned_range": (
                hilfsatz4_covers_assigned_range
            ),
            "connection_from_previous": connection,
        })
        previous_case = case
        previous_combined_range = combined_range

    first_lower = results[0]["combined_range"][0]
    last_upper = results[-1]["combined_range"][1]
    lower_endpoint_covered = (
        first_lower is None or first_lower <= family_v_lo
    )
    upper_endpoint_covered = (
        last_upper is None or last_upper >= family_v_hi
    )
    all_internal_nonempty = all(
        case_result["internal_nonempty"]["all_nonempty_for_all_c"]
        for case_result in results
    )
    all_assigned_ranges_nonempty = all(
        case_result["assigned_range_nonempty"] for case_result in results
    )
    all_hilfsatz4_checks_pass = all(
        case_result["hilfsatz4_covers_assigned_range"]
        for case_result in results
    )
    all_connections_valid = all(
        case_result["connection_from_previous"] is None
        or case_result["connection_from_previous"]["all_h1_greater"]
        for case_result in results
    )
    both_endpoints_covered = (
        lower_endpoint_covered and upper_endpoint_covered
    )

    return {
        "h": h,
        "k": k,
        "family_v_range": (family_v_lo, family_v_hi),
        "margin": margin,
        "cases": results,
        "endpoint_coverage": {
            "first_lower": first_lower,
            "family_lower": family_v_lo,
            "lower_endpoint_covered": lower_endpoint_covered,
            "last_upper": last_upper,
            "family_upper": family_v_hi,
            "upper_endpoint_covered": upper_endpoint_covered,
            "both_endpoints_covered": both_endpoints_covered,
        },
        "summary": {
            "all_internal_nonempty": all_internal_nonempty,
            "all_assigned_ranges_nonempty": all_assigned_ranges_nonempty,
            "all_hilfsatz4_checks_pass": all_hilfsatz4_checks_pass,
            "all_connections_valid": all_connections_valid,
            "both_endpoints_covered": both_endpoints_covered,
            "all_checks_pass": (
                all_internal_nonempty
                and all_assigned_ranges_nonempty
                and all_hilfsatz4_checks_pass
                and all_connections_valid
                and both_endpoints_covered
            ),
        },
    }


def print_case_family_verification(family_index, result):
    print(
        f"\ncase family 2.{family_index + 1}: "
        f"(h, k)=({result['h']}, {result['k']}), "
        f"v(A) in {result['family_v_range']}"
    )
    for case_result in result["cases"]:
        case_index = case_result["case_index"]
        connection = case_result["connection_from_previous"]
        if connection is not None:
            print(
                f"  case {case_index - 1} -> case {case_index}: "
                f"previous_upper={case_result['previous_upper']}, "
                f"effective_upper={case_result['effective_previous_upper']}, "
                f"checked={case_result['checked_v_range']}; "
                f"compared={connection['n_compared']}, "
                f"passed={connection['n_h1_greater']}, "
                f"all={connection['all_h1_greater']}"
            )

        internal = case_result["internal_nonempty"]
        print(
            f"  case {case_index}: internal iii check on "
            f"{case_result['checked_v_range']}; "
            f"compared={internal['n_compared']}, "
            f"passed={internal['n_nonempty']}, "
            f"all={internal['all_nonempty_for_all_c']}"
        )
        print(
            f"    Hilfsatz 4={case_result['hilfsatz4_range']}; "
            f"iii={case_result['iii_range']}; "
            f"intersection={case_result['combined_range']}; "
            f"checked intersection={case_result['checked_combined_range']}; "
            f"static nonempty="
            f"{case_result['static_intersection_nonempty']}"
        )
        print(
            f"    assigned={case_result['assigned_v_range']}; "
            f"nonempty={case_result['assigned_range_nonempty']}; "
            f"H4 covers assigned="
            f"{case_result['hilfsatz4_covers_assigned_range']}"
        )

    endpoint = result["endpoint_coverage"]
    print(
        f"  endpoint coverage after Hilfsatz 4: "
        f"first_lower={endpoint['first_lower']} "
        f"<= {endpoint['family_lower']}: "
        f"{endpoint['lower_endpoint_covered']}; "
        f"last_upper={endpoint['last_upper']} "
        f">= {endpoint['family_upper']}: "
        f"{endpoint['upper_endpoint_covered']}; "
        f"both={endpoint['both_endpoints_covered']}"
    )
    summary = result["summary"]
    print(
        "  family summary: "
        f"internal={summary['all_internal_nonempty']}, "
        f"assigned_nonempty={summary['all_assigned_ranges_nonempty']}, "
        f"Hilfsatz4={summary['all_hilfsatz4_checks_pass']}, "
        f"connections={summary['all_connections_valid']}, "
        f"endpoints={summary['both_endpoints_covered']}, "
        f"all={summary['all_checks_pass']}"
    )


case_family_verification_results = []
for family_index, case_family in enumerate(case_families):
    result = verify_case_family_v_cover(case_family)
    case_family_verification_results.append(result)
    print_case_family_verification(family_index, result)
# Out:
# case family 2.1: (h, k)=(0, 0), v(A) in (1, 1.98000000000000)
#   case 0: internal iii check on (1, 1.98000000000000); compared=12, passed=12, all=True
#     Hilfsatz 4=(0.910356373754828, 3.10088499093588); iii=(0.713963480223948, 1.26723050245227); intersection=(0.910356373754828, 1.26723050245227); checked intersection=(1, 1.26723050245227); static nonempty=True
#     assigned=(1, 1.26723050245227); nonempty=True; H4 covers assigned=True
#   case 0 -> case 1: previous_upper=1.26723050245227, effective_upper=1.26723050245227, checked=(1.25723050245227, 1.98000000000000); compared=6, passed=6, all=True
#   case 1: internal iii check on (1.25723050245227, 1.98000000000000); compared=6, passed=6, all=True
#     Hilfsatz 4=(0.808428126706645, 1.98750784542276); iii=(1.44759026701375, 1.99635347193077); intersection=(1.44759026701375, 1.98750784542276); checked intersection=(1.44759026701375, 1.98000000000000); static nonempty=True
# ...

# %% [markdown]
# ## Stashed / legacy experiments
#
# The cells below are retained for reference. They are not used by the
# active sequential verification pipeline above.

# %% [markdown]
# ### Legacy $T$-interval utilities

# %%
# functions related to T-interval
def _cf_candidates(side, family):
    extensions = ((1, 3), (3, 1)) if family == "eta" else ((1, 2), (2, 1))
    return [(cf_value([(0, *side), ext]), ext) for ext in extensions]

def _pick_cf(side, family, which):
    pairs = _cf_candidates(side, family)
    return (min if which == "min" else max)(pairs, key=lambda item: item[0])

def _t_interval_expression(negative_side, neg_ext, positive_side, pos_ext):
    return (0, negative_side, neg_ext, positive_side, pos_ext)

def T_interval(negative_side, positive_side):
    # return beginning/end of T_interval I(negative_side | positive_side),
    # together with expressions witnessing each endpoint

    beginning_candidates = []
    end_candidates = []

    for pos_family, neg_family in [("eta", "theta"), ("theta", "eta")]:
        pos_b, pos_ext_b = _pick_cf(positive_side, pos_family, "min")
        neg_b, neg_ext_b = _pick_cf(negative_side, neg_family, "min")
        beginning_candidates.append((
            pos_b + neg_b,
            _t_interval_expression(negative_side, neg_ext_b, positive_side, pos_ext_b),
        ))

        pos_e, pos_ext_e = _pick_cf(positive_side, pos_family, "max")
        neg_e, neg_ext_e = _pick_cf(negative_side, neg_family, "max")
        end_candidates.append((
            pos_e + neg_e,
            _t_interval_expression(negative_side, neg_ext_e, positive_side, pos_ext_e),
        ))

    beginning, beginning_expr = min(beginning_candidates, key=lambda item: item[0])
    end, end_expr = max(end_candidates, key=lambda item: item[0])
    return beginning, beginning_expr, end, end_expr

def T_ratio(negative_side, positive_side):
    # return T_ratio of I(negative_side | positive_side)
    positive_side_eta = [cf_value([(0, *positive_side), (1, 3)]), cf_value([(0, *positive_side), (3, 1)])]
    negative_side_eta = [cf_value([(0, *negative_side), (1, 3)]), cf_value([(0, *negative_side), (3, 1)])]

    return abs( (positive_side_eta[0] - positive_side_eta[1]) / (negative_side_eta[0] - negative_side_eta[1]) )

# %% [markdown]
# ### Legacy diagnostics and case analysis

# %%
def cf_extrema(term_lists):
    # return (min_value, min_terms), (max_value, max_terms) for a list of CF term lists
    valued = [(cf_value(terms), terms) for terms in term_lists]
    return (
        min(valued, key=lambda item: item[0]),
        max(valued, key=lambda item: item[0]),
    )

def sr_extrema(sr_candidates, component):
    # component: 0 for s, 1 for r; sr_candidates is e.g. sr_1[j] or sr_2[j]
    return cf_extrema(pair[component] for pair in sr_candidates)

# %%
# verify conditions and calculate admissible ranges
def check_condition_ii_endpoint_order(h, k, sr_begin, sr_end):
    # verify connectivity condition (ii) between sr_1[0] and sr_2[-1]
    (s_lo, _), (s_hi, _) = sr_extrema(sr_begin, 0)
    (r_lo, _), (r_hi, _) = sr_extrema(sr_begin, 1)
    (s2_lo, _), (s2_hi, _) = sr_extrema(sr_end, 0)
    (r2_lo, _), (r2_hi, _) = sr_extrema(sr_end, 1)

    s_ok = (s_hi <= s2_lo) if h % 2 == 0 else (s_lo >= s2_hi)
    r_ok = (r_hi <= r2_lo) if k % 2 == 0 else (r_lo >= r2_hi)
    return {"s": s_ok, "r": r_ok}


def _intersect_single_bound(a, b, how):
    """Intersect two range endpoints; None means unconstrained.
    how='lower' -> max of the two; how='upper' -> min of the two.
    """
    if a is None:
        return b
    if b is None:
        return a
    return max(a, b) if how == "lower" else min(a, b)

# %%
def print_condition_iii_bound_details(iii):
    for j, data in iii["by_j"].items():
        print(f"j={j}")
        for rec in data["records"]:
            print(
                f"  min_H={rec['min_H']}, max_H={rec['max_H']}, "
                f"r_larger={rec['r_larger']} "
                f"(r_1={rec['r_1_val']}, r_2={rec['r_2_val']})"
            )
            print(
                f"    r_1={rec['r_1']}, s_1={rec['s_1']}, "
                f"r_2={rec['r_2']}, s_2={rec['s_2']}"
            )
            print(f"    => {rec['constraint']}")
        print(f"  at j={j}: x_lower={data['x_lower']}, x_upper={data['x_upper']}")
    print(
        f"signs: (-1)^h={iii['sign_h']}, (-1)^k={iii['sign_k']}, "
        f"(-1)^(h+k)={iii['sigma']}"
    )

def print_condition_iii_transition_details(connected):
    for (j_1, j_2), data in connected["by_pair"].items():
        print(f"j_1={j_1}, j_2={j_2}  ({len(data['records'])} compared)")
        for rec in data["records"]:
            print(
                f"  {rec.get('comparison_order', 'H1 > H2')}="
                f"{rec['h1_greater']}  "
                f"r_larger_1={rec['r_larger_1']} (r_1={rec['r_1_1_val']}, r_2={rec['r_2_1_val']})  "
                f"r_larger_2={rec['r_larger_2']} (r_1={rec['r_1_2_val']}, r_2={rec['r_2_2_val']})"
            )
            print(
                f"    side1: r_1={rec['r_1_1']}, s_1={rec['s_1_1']}, "
                f"r_2={rec['r_2_1']}, s_2={rec['s_2_1']}"
            )
            print(
                f"    side2: r_1={rec['r_1_2']}, s_1={rec['s_1_2']}, "
                f"r_2={rec['r_2_2']}, s_2={rec['s_2_2']}"
            )
            print(
                f"    ranges: sr1_1={rec.get('viable_range_1_1')}, "
                f"sr2_1={rec.get('viable_range_2_1')}, "
                f"sr1_2={rec.get('viable_range_1_2')}, "
                f"sr2_2={rec.get('viable_range_2_2')}"
            )
        print(
            f"  at (j_1,j_2)=({j_1},{j_2}): "
            f"all_h1_greater={data['all_h1_greater']}"
        )
    print(
        f"signs: (-1)^h={connected['sign_h']}, (-1)^k={connected['sign_k']}, "
        f"(-1)^(h+k)={connected['sigma']}"
    )
    print(
        f"compared={connected['n_compared']}, "
        f"h1_greater={connected['n_h1_greater']}, "
        f"all_h1_greater={connected['all_h1_greater']}"
    )

# %%
def analyze_case(case, h, k, checked_v_range, previous=None):
    """Analyze one case and, when given, its connection to the previous case."""
    successors = case["intervals"]
    v_lo, v_hi = checked_v_range
    sr_1, sr_2, sr_details = select_successor_endpoint_pairs(successors, h, k, v_lo, v_hi)
    ii = check_condition_ii_endpoint_order(h, k, sr_1[0], sr_2[-1])
    iii = compute_condition_iii_v_bounds(successors, h, k, sr_1=sr_1, sr_2=sr_2, v_lo=v_lo, v_hi=v_hi)
    print_condition_iii_bound_details(iii)
    hilfsatz4 = compute_hilfsatz4_common_v_bounds(successors)
    combined_range = (
        _intersect_single_bound(
            _intersect_single_bound(iii["x_lower"], hilfsatz4["x_lower"], "lower"),
            v_lo,
            "lower",
        ),
        _intersect_single_bound(
            _intersect_single_bound(iii["x_upper"], hilfsatz4["x_upper"], "upper"),
            v_hi,
            "upper",
        ),
    )
    result = {
        "h": h,
        "k": k,
        "sr_1": sr_1,
        "sr_2": sr_2,
        "sr_details": sr_details,
        "ii": ii,
        "iii": iii,
        "hilfsatz4": hilfsatz4,
        "checked_v_range": checked_v_range,
        "combined_range": combined_range,
        "connection_from_previous": None,
    }

    if previous is not None:
        previous_case, previous_result = previous
        adjoining_v_range = (
            max(v_lo, previous_result["combined_range"][1]),
            min(v_hi, combined_range[0]),
        )
        if None in adjoining_v_range:
            raise ValueError("Cannot connect cases with an unbounded adjoining endpoint")
        needs_connection = adjoining_v_range[0] < adjoining_v_range[1]
        if needs_connection:
            iii_connected = check_condition_iii_transition(
                previous_case["intervals"], successors, h, k, *adjoining_v_range
                )
            #print_condition_iii_transition_details(iii_connected)
        result["connection_from_previous"] = {
            "v_range": adjoining_v_range,
            "needs_connection": needs_connection,
            "connected": iii_connected if needs_connection else None,
        }

    return result


def print_legacy_case_analysis(result):
    """Print the same summary values used in the proof check."""
    ii = result["ii"]
    iii = result["iii"]
    hilfsatz4 = result["hilfsatz4"]
    print(f"check (ii) s: {ii['s']}, r: {ii['r']}, all: {all(ii.values())}")
    print(
        "overall v(A) range from iii: "
        f"({iii['x_lower']}, {iii['x_upper']})"
    )
    print(
        "overall v(A) range from Hilfsatz 4: "
        f"({hilfsatz4['x_lower']}, {hilfsatz4['x_upper']})"
    )
    print(
        "overall v(A) range from iii and Hilfsatz 4: "
        f"{result['combined_range']}"
    )
    connection = result["connection_from_previous"]
    if connection is None:
        return
    if not connection["needs_connection"]:
        print(f"no gap to check in the configured range: {connection['v_range']}")
        return
    connected = connection["connected"]
    print(
        f"iii connected on {connection['v_range']}: "
        f"compared={connected['n_compared']}, "
        f"h1_greater={connected['n_h1_greater']}, "
        f"all_h1_greater={connected['all_h1_greater']}"
    )

# %%
case_results = []
for family_index, case_family in enumerate(case_families):
    h, k = case_family["hk"][0]
    family_v_lo, family_v_hi = case_family["v_range"]
    cases = case_family["cases"]
    print(
        f"\ncase family {family_index}: "
        f"(h, k)=({h}, {k}), v(A) in {case_family['v_range']}"
    )
    family_results = []
    for case_index, case in enumerate(cases):
        previous_result = family_results[-1] if family_results else None
        previous_range_ok = (
            previous_result is not None
            and previous_result["combined_range"][0]
            < previous_result["combined_range"][1]
        )
        previous = (cases[case_index - 1], previous_result) if previous_range_ok else None
        case_v_lo = (
            max(family_v_lo, previous_result["combined_range"][1] - MARGIN)
            if previous_range_ok
            else family_v_lo
        )
        checked_v_range = (case_v_lo, family_v_hi)
        result = analyze_case(case, h, k, checked_v_range, previous)
        family_results.append(result)
        print(f"case {case_index}, checked v(A) range={checked_v_range}:")
        print_legacy_case_analysis(result)
    case_results.append(family_results)
# Out:
# case family 0: (h, k)=(0, 0), v(A) in (1, 1.98000000000000)
# j=1
#   min_H=0.646133840292573, max_H=0.749650909106833, r_larger=r_2 (r_1=0.267949192431123, r_2=0.441742430504416)
#     r_1=[(0, 3), (1, 2)], s_1=[(0, 1, 1), (3, 1)], r_2=[(0, 2), (3, 1)], s_2=[(0, 2), (2, 1)]
#     => x >= 0.749650909106833
#   min_H=0.613849377791512, max_H=0.713963480223948, r_larger=r_2 (r_1=0.267949192431123, r_2=0.422649730810374)
#     r_1=[(0, 3), (1, 2)], s_1=[(0, 1, 1), (3, 1)], r_2=[(0, 2), (2, 1)], s_2=[(0, 2), (3, 1)]
#     => x >= 0.713963480223948
#   at j=1: x_lower=0.713963480223948, x_upper=None
# j=2
#   min_H=1.26723050245227, max_H=1.47056918835498, r_larger=r_1 (r_1=0.433577107400771, r_2=0.306394832501299)
#     r_1=[(0, 2, 3), (3, 1)], s_1=[(0, 2, 3), (2, 1)], r_2=[(0, 3), (3, 1)], s_2=[(0, 1, 1), (1, 2)]
#     => x <= 1.26723050245227
#   min_H=1.26388889382927, max_H=1.46430704919481, r_larger=r_1 (r_1=0.435334103144983, r_2=0.306394832501299)
# ...

# %%
iii_nonempty_results = []
for family_index, family_results in enumerate(case_results):
    family_nonempty_results = []
    for case_index, case_result in enumerate(family_results):
        result = check_condition_iii_bounds_compatible(case_result["iii"])
        family_nonempty_results.append(result)
        print(f"case family {family_index}, case {case_index}:")
        print_condition_iii_compatibility(result)
    iii_nonempty_results.append(family_nonempty_results)
# Out:
# case family 0, case 0:
# iii nonempty for every (c_plus, c_minus): upper=6, lower=2, compared=12, passed=12, all=True
# case family 0, case 1:
# iii nonempty for every (c_plus, c_minus): upper=3, lower=2, compared=6, passed=6, all=True
# case family 1, case 0:
# iii nonempty for every (c_plus, c_minus): upper=2, lower=2, compared=4, passed=4, all=True
# case family 1, case 1:
# iii nonempty for every (c_plus, c_minus): upper=4, lower=1, compared=4, passed=4, all=True
# case family 1, case 2:
# iii nonempty for every (c_plus, c_minus): upper=2, lower=2, compared=4, passed=4, all=True
# case family 2, case 0:
# iii nonempty for every (c_plus, c_minus): upper=6, lower=0, compared=0, passed=0, all=True
# case family 2, case 1:
# iii nonempty for every (c_plus, c_minus): upper=6, lower=2, compared=12, passed=12, all=True
# case family 2, case 2:
# iii nonempty for every (c_plus, c_minus): upper=5, lower=6, compared=30, passed=16, all=False
# case family 3, case 0:
# ...

# %% [markdown]
# ### Raw connectivity experiment

# %%
# Raw experiment: connect adjacent cases on the family's fixed v(A)-range.
# This deliberately does not use case_results, combined_range, or MARGIN.
raw_connected_results = []

for family_index, case_family in enumerate(case_families):
    h, k = case_family["hk"][0]
    v_lo, v_hi = case_family["v_range"]
    cases = case_family["cases"]
    family_connections = []

    print(
        f"\ncase family 2.{family_index + 1}: "
        f"(h, k)=({h}, {k}), fixed v(A)-range=({v_lo}, {v_hi})"
    )
    for right_case_index in range(1, len(cases)):
        left_case_index = right_case_index - 1
        connected = check_condition_iii_transition(
            cases[left_case_index]["intervals"],
            cases[right_case_index]["intervals"],
            h,
            k,
            v_lo,
            v_hi,
        )
        failed_records = [
            record
            for record in connected["records"]
            if not record["h1_greater"]
        ]
        family_connections.append({
            "left_case_index": left_case_index,
            "right_case_index": right_case_index,
            "v_range": (v_lo, v_hi),
            "connected": connected,
            "failed_records": failed_records,
        })
        print(
            f"  case {left_case_index} -> case {right_case_index}: "
            f"compared={connected['n_compared']}, "
            f"passed={connected['n_h1_greater']}, "
            f"failed={len(failed_records)}, "
            f"all={connected['all_h1_greater']}"
        )

    raw_connected_results.append(family_connections)
# Out:
# case family 2.1: (h, k)=(0, 0), fixed v(A)-range=(1, 1.98000000000000)
#   case 0 -> case 1: compared=15, passed=13, failed=2, all=False
#
# case family 2.2: (h, k)=(0, 0), fixed v(A)-range=(1, 1.98000000000000)
#   case 0 -> case 1: compared=5, passed=5, failed=0, all=True
#   case 1 -> case 2: compared=12, passed=12, failed=0, all=True
#
# case family 2.3: (h, k)=(0, 0), fixed v(A)-range=(1.98000000000000, 3.40000000000000)
#   case 0 -> case 1: compared=14, passed=11, failed=3, all=False
#   case 1 -> case 2: compared=24, passed=22, failed=2, all=False
#
# case family 2.4: (h, k)=(1, 0), fixed v(A)-range=(1, 1.98000000000000)
#   case 0 -> case 1: compared=6, passed=4, failed=2, all=False
#   case 1 -> case 2: compared=2, passed=1, failed=1, all=False
#   case 2 -> case 3: compared=1, passed=1, failed=0, all=True
#
# case family 2.5: (h, k)=(1, 0), fixed v(A)-range=(1, 1.98000000000000)
#   case 0 -> case 1: compared=2, passed=2, failed=0, all=True
#
# ...

# %% [markdown]
# ### Exploratory successor search

# %%
def compute_two_successor_condition_iii_bounds(
    left_interval,
    right_interval,
    hk=(0, 0),
    reverse=False,
):
    h, k = hk
    successors = [left_interval, right_interval]
    if reverse:
        successors.reverse()
    sr_1, sr_2, _ = select_successor_endpoint_pairs(successors, h, k)
    iii = compute_condition_iii_v_bounds(successors, h, k, sr_1=sr_1, sr_2=sr_2)
    return iii["x_lower"], iii["x_upper"]


def compute_hilfsatz4_bounds_for_successors(successors):
    hilfsatz4 = compute_hilfsatz4_common_v_bounds(successors)
    return hilfsatz4["x_lower"], hilfsatz4["x_upper"]

# %%
from itertools import product


def enumerate_sequences_upto_depth(depth, nums=(1, 2, 3)):
    """Enumerate all sequences over nums up to depth, including []."""
    return [
        list(sequence)
        for length in range(depth + 1)
        for sequence in product(nums, repeat=length)
    ]


def find_successors_matching_v_bounds(
    left_interval,
    right_interval,
    depth,
    max_lower_bound,
    min_upper_bound,
    nums=(1, 2, 3),
    hk=(0, 0),
):
    """Find candidate intervals whose two calculated ranges pass the bounds.

    The inequalities and boundary conventions are intentionally unchanged
    from the original experiment.
    """
    results = []
    candidates = enumerate_sequences_upto_depth(depth, nums)

    for left_sequence in candidates:
        for right_sequence in candidates:
            connected_range = compute_two_successor_condition_iii_bounds(
                (left_interval, right_interval),
                (left_sequence, right_sequence),
                hk=hk,
                reverse=False,
            )
            admissible_range = compute_hilfsatz4_bounds_for_successors(
                [(left_sequence, right_sequence)]
            )
            minimum = max(connected_range[0], admissible_range[0])
            maximum = min(connected_range[1], admissible_range[1])
            if minimum < max_lower_bound and maximum > min_upper_bound:
                results.append({
                    "left_seq": left_sequence,
                    "right_seq": right_sequence,
                    "compute_two_successor_condition_iii_bounds": connected_range,
                    "compute_hilfsatz4_bounds_for_successors": admissible_range,
                })
    return results

# %%
print(compute_two_successor_condition_iii_bounds(([2], [3]), ([], [2]), reverse=False))
print(compute_hilfsatz4_bounds_for_successors([([], [2])]))

search_1 = find_successors_matching_v_bounds([], [1], 3, 1.0, 1.9)
search_2 = find_successors_matching_v_bounds([3, 1], [2, 3], 3, 1.0, 1.9)
search_3 = find_successors_matching_v_bounds([2], [3], 3, 1.0, 1.9)

print(search_1)
print(search_2)
search_3
# Out:
# (None, 2.27805611745193)
# (1.77765186408743, 18.7417995471568)
# ...

# %% [markdown]
# ### Numerical $T$-interval experiment

# %%
def compute_successor_t_intervals(A, successors):
    """Calculate the T-interval and T-ratio for every successor."""
    t_intervals = []
    for j, successor in enumerate(successors):
        negative_side = list(A[0]) + list(successor[0])
        positive_side = list(A[1]) + list(successor[1])
        left, left_expr, right, right_expr = T_interval(
            negative_side, positive_side
        )
        t_intervals.append({
            "j": j,
            "successor": successor,
            "negative_side": negative_side,
            "positive_side": positive_side,
            "left": left,
            "right": right,
            "left_expr": left_expr,
            "right_expr": right_expr,
            "t_ratio": T_ratio(negative_side, positive_side),
        })
    return t_intervals


def analyze_interval_union(t_intervals):
    """Return whether the interval union is connected and list its gaps."""
    ordered = sorted(
        range(len(t_intervals)),
        key=lambda i: (t_intervals[i]["left"], t_intervals[i]["right"]),
    )
    gaps = []
    components = []
    if not ordered:
        return {"connected": True, "gaps": gaps, "components": components}

    component_start = t_intervals[ordered[0]]["left"]
    component_end = t_intervals[ordered[0]]["right"]
    component_members = [ordered[0]]
    for idx in ordered[1:]:
        left = t_intervals[idx]["left"]
        right = t_intervals[idx]["right"]
        if left <= component_end:
            component_end = max(component_end, right)
            component_members.append(idx)
        else:
            components.append({
                "start": component_start,
                "end": component_end,
                "members": list(component_members),
            })
            gaps.append({
                "gap": (component_end, left),
                "left_component": list(component_members),
                "next_j": idx,
            })
            component_start = left
            component_end = right
            component_members = [idx]

    components.append({
        "start": component_start,
        "end": component_end,
        "members": list(component_members),
    })
    return {
        "connected": not gaps,
        "gaps": gaps,
        "components": components,
    }


successors = [
                ([3], [2]),
                ([2, 1], [3]),
                ([2, 1, 3], [2, 1, 3]),
                ([2], [2]),
            ]
A = ([3], [2])

print(T_ratio(A[0], A[1]))
t_intervals = compute_successor_t_intervals(A, successors)
for interval in t_intervals:
    print(
        f"j={interval['j']}, successor={interval['successor']}, "
        f"I({interval['negative_side']}|{interval['positive_side']}) = "
        f"[{interval['left']}, {interval['right']}], "
        f"T-ratio: {interval['t_ratio']}"
    )

union = analyze_interval_union(t_intervals)
for gap in union["gaps"]:
    print(
        f"gap: {gap['gap']} between component "
        f"{gap['left_component']} and j={gap['next_j']}"
    )
final_component = union["components"][-1]
print(
    f"final component covering "
    f"[{final_component['start']}, {final_component['end']}], "
    f"members={final_component['members']}"
)
print(f"union connected: {union['connected']}")
if union["gaps"]:
    print(f"number of gaps: {len(union['gaps'])}")
# Out:
# 1.95825756949558
# j=0, successor=([3], [2]), I([3, 3]|[2, 2]) = [0.712841703803748, 0.730044200759777], T-ratio: 3.66988118487039
# j=1, successor=([2, 1], [3]), I([3, 2, 1]|[2, 3]) = [0.728736895861416, 0.738828720725427], T-ratio: 2.84929721028392
# j=2, successor=([2, 1, 3], [2, 1, 3]), I([3, 2, 1, 3]|[2, 2, 1, 3]) = [0.720981829457886, 0.721785599500979], T-ratio: 2.02703994658336
# j=3, successor=([2], [2]), I([3, 2]|[2, 2]) = [0.701714899814108, 0.721128181545839], T-ratio: 2.00724914264439
# final component covering [0.701714899814108, 0.738828720725427], members=[3, 0, 2, 1]
# union connected: True
